# %% [markdown]
# <a href="https://colab.research.google.com/github/Mountain-Biker/pydata-book-practice/blob/main/chapter5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Chapter 5. Getting Started with pandas

# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame

# %% [markdown]
# ## 5.1 Introduction to pandas Data Structures

# %% [markdown]
# ### Series
#
# A Series is a one-dimensional array-like object containing a sequence of values of the same type and an associated array of data labels, called its index.

# %%
obj = pd.Series([4, 5, -7, 3])

# %%
obj
# Out:
# 0    4
# 1    5
# 2   -7
# 3    3
# dtype: int64

# %%
obj2 = pd.Series([1, 2, 3, 4], index=['a', 'b', 'c', 'd'])

# %%
obj2
# Out:
# a    1
# b    2
# c    3
# d    4
# dtype: int64

# %%
obj2.index
# Out:
# Index(['a', 'b', 'c', 'd'], dtype='object')

# %%
obj2['a']
# Out:
# 1

# %%
obj2['b'] = 6

# %%
obj2[['a', 'b']] = -1

# %%
obj2
# Out:
# a   -1
# b   -1
# c    3
# d    4
# dtype: int64

# %% [markdown]
# Using Numpy functions or Numpy-like operations, such as filtering with a Boolean array, scalar multiplication, or applying math functions, will preserve the index-value relationship.

# %%
obj2[obj2 > 0]
# Out:
# c    3
# d    4
# dtype: int64

# %%
obj2 * 2
# Out:
# a   -2
# b   -2
# c    6
# d    8
# dtype: int64

# %%
np.exp(obj2)
# Out:
# a     0.367879
# b     0.367879
# c    20.085537
# d    54.598150
# dtype: float64

# %% [markdown]
# Another way to think about a Series is as a **fixed-length, ordered dictionary**, as it is a mapping of index values to data values. It can be used in many context where you might use a dictionary.

# %%
'b' in obj2
# Out:
# True

# %%
'e' in obj2
# Out:
# False

# %% [markdown]
# A series can be created from a dictionary.

# %%
sdata = {'Ohio': 35000, 'Texas': 71000, 'Oregon': 16000, 'Utah': 5000}
obj3 = pd.Series(sdata)
obj3
# Out:
# Ohio      35000
# Texas     71000
# Oregon    16000
# Utah       5000
# dtype: int64

# %% [markdown]
# A series can be converted back to a dictionary with its to_dict method.

# %%
obj3.to_dict()
# Out:
# {'Ohio': 35000, 'Texas': 71000, 'Oregon': 16000, 'Utah': 5000}

# %%
states = ['California', 'Utah', 'Oregon', 'Texas']
obj4 = pd.Series(sdata, index=states)

# %%
obj4
# Out:
# California        NaN
# Utah           5000.0
# Oregon        16000.0
# Texas         71000.0
# dtype: float64

# %% [markdown]
# The isna and notna functions in pandas should be used to detect missing data.

# %%
pd.isna(obj4)
# Out:
# California     True
# Utah          False
# Oregon        False
# Texas         False
# dtype: bool

# %%
obj4.isna()
# Out:
# California     True
# Utah          False
# Oregon        False
# Texas         False
# dtype: bool

# %% [markdown]
# A useful Series feature for many applications is that it automatically aligns by index label in arithmetic operations:

# %%
obj3 + obj4
# Out:
# California         NaN
# Ohio               NaN
# Oregon         32000.0
# Texas         142000.0
# Utah           10000.0
# dtype: float64

# %% [markdown]
# ### DataFrame
