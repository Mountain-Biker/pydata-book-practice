# %% [markdown]
# <a href="https://colab.research.google.com/github/Mountain-Biker/pydata-book-practice/blob/main/chapter5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Chapter 5. Getting Started with pandas

# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame

# %% [markdown]
# ## 5.1 Introduction to pandas Data Structures

# %% [markdown]
# ### Series
#
# A Series is a one-dimensional array-like object containing a sequence of values of the same type and an associated array of data labels, called its index.

# %%
obj = pd.Series([4, 5, -7, 3])

# %%
obj
# Out:
# 0    4
# 1    5
# 2   -7
# 3    3
# dtype: int64

# %%
obj2 = pd.Series([1, 2, 3, 4], index=['a', 'b', 'c', 'd'])

# %%
obj2
# Out:
# a    1
# b    2
# c    3
# d    4
# dtype: int64

# %%
obj2.index
# Out:
# Index(['a', 'b', 'c', 'd'], dtype='object')

# %%
obj2['a']
# Out:
# np.int64(1)

# %%
obj2['b'] = 6

# %%
obj2[['a', 'b']] = -1

# %%
obj2
# Out:
# a   -1
# b   -1
# c    3
# d    4
# dtype: int64

# %% [markdown]
# Using Numpy functions or Numpy-like operations, such as filtering with a Boolean array, scalar multiplication, or applying math functions, will preserve the index-value relationship.

# %%
obj2[obj2 > 0]
# Out:
# c    3
# d    4
# dtype: int64

# %%
obj2 * 2
# Out:
# a   -2
# b   -2
# c    6
# d    8
# dtype: int64

# %%
np.exp(obj2)
# Out:
# a     0.367879
# b     0.367879
# c    20.085537
# d    54.598150
# dtype: float64

# %% [markdown]
# Another way to think about a Series is as a **fixed-length, ordered dictionary**, as it is a mapping of index values to data values. It can be used in many context where you might use a dictionary.

# %%
'b' in obj2
# Out:
# True

# %%
'e' in obj2
# Out:
# False

# %% [markdown]
# A series can be created from a dictionary.

# %%
sdata = {'Ohio': 35000, 'Texas': 71000, 'Oregon': 16000, 'Utah': 5000}
obj3 = pd.Series(sdata)
obj3
# Out:
# Ohio      35000
# Texas     71000
# Oregon    16000
# Utah       5000
# dtype: int64

# %% [markdown]
# A series can be converted back to a dictionary with its to_dict method.

# %%
obj3.to_dict()
# Out:
# {'Ohio': 35000, 'Texas': 71000, 'Oregon': 16000, 'Utah': 5000}

# %%
states = ['California', 'Utah', 'Oregon', 'Texas']
obj4 = pd.Series(sdata, index=states)

# %%
obj4
# Out:
# California        NaN
# Utah           5000.0
# Oregon        16000.0
# Texas         71000.0
# dtype: float64

# %% [markdown]
# The isna and notna functions in pandas should be used to detect missing data.

# %%
pd.isna(obj4)
# Out:
# California     True
# Utah          False
# Oregon        False
# Texas         False
# dtype: bool

# %%
obj4.isna()
# Out:
# California     True
# Utah          False
# Oregon        False
# Texas         False
# dtype: bool

# %% [markdown]
# A useful Series feature for many applications is that it automatically aligns by index label in arithmetic operations:

# %%
obj3 + obj4
# Out:
# California         NaN
# Ohio               NaN
# Oregon         32000.0
# Texas         142000.0
# Utah           10000.0
# dtype: float64

# %% [markdown]
# ### DataFrame

# %% [markdown]
# There are many ways to construct a DataFrame, though one of the most common is from a dictionary of equal-length lists or NumPy arrays.

# %%
data = {'state': ['Ohio', 'Ohio', 'Ohio', 'Nevada', 'Nevada', 'Nevada'],
        'year': [2000, 2001, 2002, 2001, 2002, 2003],
        'pop': [1.5, 1.7, 3.6, 2.4, 2.9, 3.2]}
frame = pd.DataFrame(data)

# %%
frame
# Out:
#     state  year  pop
# 0    Ohio  2000  1.5
# 1    Ohio  2001  1.7
# 2    Ohio  2002  3.6
# 3  Nevada  2001  2.4
# 4  Nevada  2002  2.9
# 5  Nevada  2003  3.2

# %%
# head method selects only the first five rows
frame.head()
# Out:
#     state  year  pop
# 0    Ohio  2000  1.5
# 1    Ohio  2001  1.7
# 2    Ohio  2002  3.6
# 3  Nevada  2001  2.4
# 4  Nevada  2002  2.9

# %%
# tail method selects only the last five rows
frame.tail()
# Out:
#     state  year  pop
# 1    Ohio  2001  1.7
# 2    Ohio  2002  3.6
# 3  Nevada  2001  2.4
# 4  Nevada  2002  2.9
# 5  Nevada  2003  3.2

# %% [markdown]
# If you sepcify a sequence of columns, the DataFrame's columns will be arranged in that order.

# %%
pd.DataFrame(data, columns=['year', 'state', 'pop'])
# Out:
#    year   state  pop
# 0  2000    Ohio  1.5
# 1  2001    Ohio  1.7
# 2  2002    Ohio  3.6
# 3  2001  Nevada  2.4
# 4  2002  Nevada  2.9
# 5  2003  Nevada  3.2

# %% [markdown]
# If you pass a column that isn't contained in the dictionary, it will appear with missing values in the result:

# %%
frame2 = pd.DataFrame(data, columns=['year', 'state', 'pop', 'debt'])
frame2
# Out:
#    year   state  pop debt
# 0  2000    Ohio  1.5  NaN
# 1  2001    Ohio  1.7  NaN
# 2  2002    Ohio  3.6  NaN
# 3  2001  Nevada  2.4  NaN
# 4  2002  Nevada  2.9  NaN
# 5  2003  Nevada  3.2  NaN

# %% [markdown]
# A column in a DataFrame can be retrieved as a Series either by dictionary-like notation or by using the dot attribute notation.

# %%
frame2['state']
# Out:
# 0      Ohio
# 1      Ohio
# 2      Ohio
# 3    Nevada
# 4    Nevada
# 5    Nevada
# Name: state, dtype: object

# %%
frame2.state
# Out:
# 0      Ohio
# 1      Ohio
# 2      Ohio
# 3    Nevada
# 4    Nevada
# 5    Nevada
# Name: state, dtype: object

# %% [markdown]
# Rows can be retrieved by position or name with the special iloc and loc attributes.

# %%
frame2.loc[1]
# Out:
# year     2001
# state    Ohio
# pop       1.7
# debt      NaN
# Name: 1, dtype: object

# %%
frame2.iloc[2]
# Out:
# year     2002
# state    Ohio
# pop       3.6
# debt      NaN
# Name: 2, dtype: object

# %% [markdown]
# Columns can be modified by assignment. A column can be assigned a scalar value or an array of values.

# %%
frame2['debt'] = 16.5
frame2
# Out:
#    year   state  pop  debt
# 0  2000    Ohio  1.5  16.5
# 1  2001    Ohio  1.7  16.5
# 2  2002    Ohio  3.6  16.5
# 3  2001  Nevada  2.4  16.5
# 4  2002  Nevada  2.9  16.5
# 5  2003  Nevada  3.2  16.5

# %%
frame2.debt = np.arange(0.0, 6)
frame2
# Out:
#    year   state  pop  debt
# 0  2000    Ohio  1.5   0.0
# 1  2001    Ohio  1.7   1.0
# 2  2002    Ohio  3.6   2.0
# 3  2001  Nevada  2.4   3.0
# 4  2002  Nevada  2.9   4.0
# 5  2003  Nevada  3.2   5.0

# %% [markdown]
# When you are assigning lists or arrays to a column, the value's length must match the length of the DataFrame. If you assign a Series, its labels will be realigned exactly to the DataFrame's index, inserting missing values in any index values not present.

# %%
val = pd.Series([-1.2, -1.5, -1.7, 1.23], index=['two', 'four', 'five', 0])

# %%
frame2['debt'] = val
frame2
# Out:
#    year   state  pop  debt
# 0  2000    Ohio  1.5  1.23
# 1  2001    Ohio  1.7   NaN
# 2  2002    Ohio  3.6   NaN
# 3  2001  Nevada  2.4   NaN
# 4  2002  Nevada  2.9   NaN
# 5  2003  Nevada  3.2   NaN

# %% [markdown]
# Assigning a column that doesn't exist will create a new column. New column cannot be created with the frame2.eastern dot attribute notation.

# %%
frame2['eastern'] = frame2['state'] == 'Ohio'
frame2
# Out:
#    year   state  pop  debt  eastern
# 0  2000    Ohio  1.5  1.23     True
# 1  2001    Ohio  1.7   NaN     True
# 2  2002    Ohio  3.6   NaN     True
# 3  2001  Nevada  2.4   NaN    False
# 4  2002  Nevada  2.9   NaN    False
# 5  2003  Nevada  3.2   NaN    False

# %% [markdown]
# The `del` method can be used to remove a column.

# %%
del frame2['eastern']

# %%
frame2.columns
# Out:
# Index(['year', 'state', 'pop', 'debt'], dtype='object')

# %%
df1 =  frame2[['year', 'debt']]
print(df1._is_view)

df2 = frame2[['year', 'state']]
print(df2._is_view)
# Out:
# False
# False

# %% [markdown]
# ### Index Objects

# %% [markdown]
# pandas's Index objects are repsonsible for holding the axis labels (including a DataFrame's column names) and other metadata.

# %%
obj = pd.Series(np.arange(3), index=['a', 'b', 'c'])

# %%
index = obj.index

# %%
index
# Out:
# Index(['a', 'b', 'c'], dtype='object')

# %% [markdown]
# Index objects are immutable and thus can't be modified by the user.

# %%
# index[1] = 'd'

# %%
obj2 = pd.Series([1.5, -2.5, 0], index=index)

# %%
obj2.index is index
# Out:
# True

# %% [markdown]
# In addition to being array-like, an Index also behaves like a fixed-size set.

# %%
frame3 = pd.DataFrame({'Ohio': {2000: 1.5, 2001: 1.7, 2002: 3.6},
                       'Nevada': {2001: 2.4, 2002: 2.9},
                       })

# %%
frame3
# Out:
#       Ohio  Nevada
# 2000   1.5     NaN
# 2001   1.7     2.4
# 2002   3.6     2.9

# %%
frame3.columns
# Out:
# Index(['Ohio', 'Nevada'], dtype='object')

# %%
'Ohio' in frame3.columns
# Out:
# True

# %% [markdown]
# ## 5.2 Essential Functionality

# %% [markdown]
# ### Reindexing

# %%
obj = pd.Series([4.5, 7.2, -5.3, 3.6], index=['d', 'b', 'a', 'c'])

# %%
obj
# Out:
# d    4.5
# b    7.2
# a   -5.3
# c    3.6
# dtype: float64

# %% [markdown]
# Calling reindex on the Series rearranges the data according to the new index, introducing missing values if any index values were not already present.

# %%
obj2 = obj.reindex(['a', 'b', 'c', 'd', 'e'])

# %%
obj2
# Out:
# a   -5.3
# b    7.2
# c    3.6
# d    4.5
# e    NaN
# dtype: float64

# %%
obj3 = pd.Series(['blue', 'purple', 'yellow'], index=[0, 2, 4])

# %%
obj3
# Out:
# 0      blue
# 2    purple
# 4    yellow
# dtype: object

# %%
obj3.reindex(np.arange(6), method='ffill')
# Out:
# 0      blue
# 1      blue
# 2    purple
# 3    purple
# 4    yellow
# 5    yellow
# dtype: object

# %% [markdown]
# With DataFrame, reindex can alter the row index, columns or both.

# %%
frame = pd.DataFrame(np.arange(9).reshape((3, 3)),
                     index=['a', 'c', 'd'],
                     columns=['Ohio', 'Texas', 'California'])

# %%
frame
# Out:
#    Ohio  Texas  California
# a     0      1           2
# c     3      4           5
# d     6      7           8

# %%
frame2 = frame.reindex(index=['a', 'b', 'c', 'd'])
frame2
# Out:
#    Ohio  Texas  California
# a   0.0    1.0         2.0
# b   NaN    NaN         NaN
# c   3.0    4.0         5.0
# d   6.0    7.0         8.0

# %% [markdown]
# The columns can be reindexed with the columns keyword. Because 'Ohio' was not in states, the data for that column is dropped from the result.

# %%
states = ['Texas', 'Utah', 'California']
frame3 = frame.reindex(columns=states)
frame3
# Out:
#    Texas  Utah  California
# a      1   NaN           2
# c      4   NaN           5
# d      7   NaN           8

# %% [markdown]
# We can also reindex by using the loc operator, and many users prefer to do it this way. This works only if all of the new index labels already exist in the DataFrame (whereas reindex will insert missing data for new labels)

# %%
frame
# Out:
#    Ohio  Texas  California
# a     0      1           2
# c     3      4           5
# d     6      7           8

# %%
frame4 = frame.loc[['a', 'd', 'c'], ['Texas', 'Ohio']]
frame4
# Out:
#    Texas  Ohio
# a      1     0
# d      7     6
# c      4     3

# %%
frame4._is_view
# Out:
# True

# %% [markdown]
# ### Dropping Entries from an Axis

# %%
obj = pd.Series(np.arange(5), index=['a', 'b', 'c', 'd', 'e'])

# %%
new_obj = obj.drop('c')

# %%
new_obj
# Out:
# a    0
# b    1
# d    3
# e    4
# dtype: int64

# %%
data = pd.DataFrame(np.arange(16).reshape((4, 4)),
                    index=['Ohio', 'Colorado', 'Utah', 'New York'],
                    columns=['one', 'two', 'three', 'four'])

# %%
data
# Out:
#           one  two  three  four
# Ohio        0    1      2     3
# Colorado    4    5      6     7
# Utah        8    9     10    11
# New York   12   13     14    15

# %% [markdown]
# Calling drop with a sequence of labels will drop values from the row labels.

# %%
data.drop(['Colorado', 'Ohio'])
# Out:
#           one  two  three  four
# Utah        8    9     10    11
# New York   12   13     14    15

# %%
data.drop(index=['Colorado', 'Ohio'])
# Out:
#           one  two  three  four
# Utah        8    9     10    11
# New York   12   13     14    15

# %% [markdown]
# To drop labels from the columns, use the columns keyword.

# %%
data.drop(columns=['two'])
# Out:
#           one  three  four
# Ohio        0      2     3
# Colorado    4      6     7
# Utah        8     10    11
# New York   12     14    15

# %%
data.drop(['two', 'four'], axis=1)
# Out:
#           one  three
# Ohio        0      2
# Colorado    4      6
# Utah        8     10
# New York   12     14

# %% [markdown]
# ### Indexing, Selection and Filtering

# %%
obj = pd.Series(np.arange(4.), index=['a', 'b', 'c', 'd'])

# %%
obj['a']
# Out:
# np.float64(0.0)

# %%
# Not a good way to use integer position to access a value in Series
# Should use obj.iloc[] instead
obj[1]
# Out:
# <ipython-input-77-0ceebe4fe905>:3: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   obj[1]
# np.float64(1.0)

# %%
obj[[1, 2]]
# Out:
# <ipython-input-78-76ca706e5645>:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   obj[[1, 2]]
# b    1.0
# c    2.0
# dtype: float64

# %%
obj[['b', 'c', 'a']]
# Out:
# b    1.0
# c    2.0
# a    0.0
# dtype: float64

# %%
obj[obj < 2]
# Out:
# a    0.0
# b    1.0
# dtype: float64

# %%
obj.loc[['b', 'a', 'd']]
# Out:
# b    1.0
# a    0.0
# d    3.0
# dtype: float64

# %% [markdown]
# When using `loc`, the expression `obj.loc[[0, 1, 2]]` will fail when the index does not contain integers.

# %%
# obj.loc[[0]]

# %% [markdown]
# Since `loc` operator indexes exclusively with labels, there is also an iloc operator that indexes exclusively with integers to work consistently whether or not the index contains integers.

# %%
obj.iloc[[1, 2]]
# Out:
# b    1.0
# c    2.0
# dtype: float64

# %%
obj.loc['c': 'd']
# Out:
# c    2.0
# d    3.0
# dtype: float64

# %%
data = pd.DataFrame(np.arange(16).reshape((4, 4)),
                    index=['Ohio', 'Colorado', 'Utah', 'Nevada'],
                    columns=['one', 'two', 'three', 'four'])

# %%
data
# Out:
#           one  two  three  four
# Ohio        0    1      2     3
# Colorado    4    5      6     7
# Utah        8    9     10    11
# Nevada     12   13     14    15

# %% [markdown]
# Indexing into a DataFrame retrieves one or more columns either with a single value or sequence:

# %%
data['two']
# Out:
# Ohio         1
# Colorado     5
# Utah         9
# Nevada      13
# Name: two, dtype: int64

# %%
data[['two', 'three']]
# Out:
#           two  three
# Ohio        1      2
# Colorado    5      6
# Utah        9     10
# Nevada     13     14

# %% [markdown]
# If we want to retrieve rows with indexing, we should use integer positions:

# %%
data[0:2]
# Out:
#           one  two  three  four
# Ohio        0    1      2     3
# Colorado    4    5      6     7

# %%
data < 5
# Out:
#             one    two  three   four
# Ohio       True   True   True   True
# Colorado   True  False  False  False
# Utah      False  False  False  False
# Nevada    False  False  False  False

# %%
data[data < 5]
# Out:
#           one  two  three  four
# Ohio      0.0  1.0    2.0   3.0
# Colorado  4.0  NaN    NaN   NaN
# Utah      NaN  NaN    NaN   NaN
# Nevada    NaN  NaN    NaN   NaN

# %% [markdown]
# ### Selection on DataFrame with loc and iloc

# %%
data.loc['Colorado']
# Out:
# one      4
# two      5
# three    6
# four     7
# Name: Colorado, dtype: int64

# %%
data.loc[['Colorado', 'Utah']]
# Out:
#           one  two  three  four
# Colorado    4    5      6     7
# Utah        8    9     10    11

# %%
data.loc[['Utah', 'Nevada'], 'one']
# Out:
# Utah       8
# Nevada    12
# Name: one, dtype: int64

# %%
data.iloc[2]
# Out:
# one       8
# two       9
# three    10
# four     11
# Name: Utah, dtype: int64

# %%
data.iloc[[2, 1]]
# Out:
#           one  two  three  four
# Utah        8    9     10    11
# Colorado    4    5      6     7

# %%
data.iloc[[2, 1], [1, 3]]
# Out:
#           two  four
# Utah        9    11
# Colorado    5     7

# %%
data.iloc[:, 1]
# Out:
# Ohio         1
# Colorado     5
# Utah         9
# Nevada      13
# Name: two, dtype: int64

# %% [markdown]
# ### Pitfalls with Chained indexing

# %% [markdown]
# When trying to modify values in a dataframe in place, we should always use loc and iloc.

# %%
data.loc[data.three > 5]['three'] = 6
# Out:
# <ipython-input-99-e95134e02e88>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.loc[data.three > 5]['three'] = 6

# %% [markdown]
# The above code will return a SettingWithCopyWarning, because `data.loc[data.three > 5]` will return a copy of the original DataFrame. So the code will modify the copy of the dataframe but not the origial one. To fix the issue, we should use a single loc operation:

# %%
data.loc[data.three > 5, 'three'] = 6

# %%
data
# Out:
#           one  two  three  four
# Ohio        0    1      2     3
# Colorado    4    5      6     7
# Utah        8    9      6    11
# Nevada     12   13      6    15

# %% [markdown]
# ### Arithmetic and Data Alignment

# %% [markdown]
# When you add objects, if any index pairs are not the same, the respective index in the result will be the union of the index pairs. The internal data alignment introduces missing values in the label locations that don't overlap.

# %%
s1 = pd.Series([7, -2, 3, 1], index=['a', 'b', 'c', 'e'])

# %%
s2 = pd.Series([2, 3, 4], index=['a', 'c', 'd'])

# %%
s1 + s2
# Out:
# a    9.0
# b    NaN
# c    6.0
# d    NaN
# e    NaN
# dtype: float64

# %%
df1 = pd.DataFrame(np.arange(0, 9.0).reshape((3, 3)),
                   columns=list('bcd'),
                   index=['Utah', 'Colorado', 'Nevada'])
df1
# Out:
#             b    c    d
# Utah      0.0  1.0  2.0
# Colorado  3.0  4.0  5.0
# Nevada    6.0  7.0  8.0

# %%
df2 = pd.DataFrame(np.arange(0, 12.0).reshape((4, 3)),
                   columns=list('bde'),
                   index=['Ohio', 'Utah', 'Nevada', 'Colorado'])
df2
# Out:
#             b     d     e
# Ohio      0.0   1.0   2.0
# Utah      3.0   4.0   5.0
# Nevada    6.0   7.0   8.0
# Colorado  9.0  10.0  11.0

# %%
df1 + df2
# Out:
#              b   c     d   e
# Colorado  12.0 NaN  15.0 NaN
# Nevada    12.0 NaN  15.0 NaN
# Ohio       NaN NaN   NaN NaN
# Utah       3.0 NaN   6.0 NaN

# %% [markdown]
# #### Arithmetic methods with fill values

# %%
df1.add(df2, fill_value=0)
# Out:
#              b    c     d     e
# Colorado  12.0  4.0  15.0  11.0
# Nevada    12.0  7.0  15.0   8.0
# Ohio       0.0  NaN   1.0   2.0
# Utah       3.0  1.0   6.0   5.0

# %% [markdown]
# #### Operations between DataFrame and Series

# %%
arr = np.arange(12.).reshape((3, 4))

# %%
# broadcasting in np array
arr - arr[0]
# Out:
# array([[0., 0., 0., 0.],
#        [4., 4., 4., 4.],
#        [8., 8., 8., 8.]])

# %%
frame = pd.DataFrame(np.arange(12.).reshape((4, 3)),
                     columns=list('bde'),
                     index=['Utah', 'Colorado', 'Ohio', 'Nevada'])

# %%
series = frame.iloc[0]
series
# Out:
# b    0.0
# d    1.0
# e    2.0
# Name: Utah, dtype: float64

# %%
print(series.index)
# Out:
# Index(['b', 'd', 'e'], dtype='object')

# %% [markdown]
# By default, arithmetic between DataFrame and Series matches the index of the Series on the columns of the DataFrame, broadcasting down the rows:

# %%
frame - series
# Out:
#             b    d    e
# Utah      0.0  0.0  0.0
# Colorado  3.0  3.0  3.0
# Ohio      6.0  6.0  6.0
# Nevada    9.0  9.0  9.0

# %%
series3 = frame['d']
print(series3.index)
series3
# Out:
# Index(['Utah', 'Colorado', 'Ohio', 'Nevada'], dtype='object')
# Utah         1.0
# Colorado     4.0
# Ohio         7.0
# Nevada      10.0
# Name: d, dtype: float64

# %% [markdown]
# If you want to instead broadcast over the columns, matching on the rows, you have to use one of the arithmetic methods and specify to match over the index.

# %%
frame.sub(series3, axis='index')
# Out:
#             b    d    e
# Utah     -1.0  0.0  1.0
# Colorado -1.0  0.0  1.0
# Ohio     -1.0  0.0  1.0
# Nevada   -1.0  0.0  1.0

# %% [markdown]
# ### Function Application and Mapping
